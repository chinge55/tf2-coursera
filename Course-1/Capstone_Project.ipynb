# %% [markdown]
# # Capstone Project
# ## Image classifier for the SVHN dataset
# ### Instructions
#
# In this notebook, you will create a neural network that classifies real-world images digits. You will use concepts from throughout this course in building, training, testing, validating and saving your Tensorflow classifier model.
#
# This project is peer-assessed. Within this notebook you will find instructions in each section for how to complete the project. Pay close attention to the instructions as the peer review will be carried out according to a grading rubric that checks key parts of the project instructions. Feel free to add extra cells into the notebook as required.
#
# ### How to submit
#
# When you have completed the Capstone project notebook, you will submit a pdf of the notebook for peer review. First ensure that the notebook has been fully executed from beginning to end, and all of the cell outputs are visible. This is important, as the grading rubric depends on the reviewer being able to view the outputs of your notebook. Save the notebook as a pdf (you could download the notebook with File -> Download .ipynb, open the notebook locally, and then File -> Download as -> PDF via LaTeX), and then submit this pdf for review.
#
# ### Let's get started!
#
# We'll start by running some imports, and loading the dataset. For this project you are free to make further imports throughout the notebook as you wish.

# %%
import tensorflow as tf
from scipy.io import loadmat
import numpy as np
from matplotlib import pyplot as plt
from sklearn.preprocessing import LabelBinarizer

# %% [markdown]
# For the capstone project, you will use the [SVHN dataset](http://ufldl.stanford.edu/housenumbers/). This is an image dataset of over 600,000 digit images in all, and is a harder dataset than MNIST as the numbers appear in the context of natural scene images. SVHN is obtained from house numbers in Google Street View images.
#
# * Y. Netzer, T. Wang, A. Coates, A. Bissacco, B. Wu and A. Y. Ng. "Reading Digits in Natural Images with Unsupervised Feature Learning". NIPS Workshop on Deep Learning and Unsupervised Feature Learning, 2011.
#
# The train and test datasets required for this project can be downloaded from [here](http://ufldl.stanford.edu/housenumbers/train.tar.gz) and [here](http://ufldl.stanford.edu/housenumbers/test.tar.gz). Once unzipped, you will have two files: `train_32x32.mat` and `test_32x32.mat`. You should store these files in Drive for use in this Colab notebook.
#
# Your goal is to develop an end-to-end workflow for building, training, validating, evaluating and saving a neural network that classifies a real-world image into one of ten classes.

# %%
# Run this cell to connect to your Drive folder

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Load the dataset from your Drive folder

train = loadmat('/content/gdrive/My Drive/coursera-capstone/train_32x32.mat')
test = loadmat('/content/gdrive/My Drive/coursera-capstone/test_32x32.mat')

# %% [markdown]
# Both `train` and `test` are dictionaries with keys `X` and `y` for the input images and labels respectively.

# %% [markdown]
# ## 1. Inspect and preprocess the dataset
# * Extract the training and testing images and labels separately from the train and test dictionaries loaded for you.
# * Select a random sample of images and corresponding labels from the dataset (at least 10), and display them in a figure.
# * Convert the training and test images to grayscale by taking the average across all colour channels for each pixel. _Hint: retain the channel dimension, which will now have size 1._
# * Select a random sample of the grayscale images and corresponding labels from the dataset (at least 10), and display them in a figure.

# %%
x_train = train['X']
y_train = train['y']
x_test = test['X']
y_test = test['y']
y_test = np.where(y_test == 10, 0, y_test )
y_train = np.where(y_train == 10, 0, y_train )

# %%
x_train = np.moveaxis(x_train, -1, 0)
x_test = np.moveaxis(x_test, -1, 0)

# %%
fig, ax = plt.subplots(1, 10, figsize=(10, 1))

for i in range(10):
    a = np.random.randint(0,7000)
    ax[i].set_axis_off()
    ax[i].imshow(x_train[a])
    print(y_train[a])
# Out:
# [7]
# [2]
# [3]
# [5]
# [2]
# [5]
# [1]
# [0]
# [4]
# [1]

# %%
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (73257, 32, 32, 3) (73257, 1)
# (26032, 32, 32, 3) (26032, 1)

# %%
x_train = np.mean(x_train, axis = -1)
x_test = np.mean(x_test, axis = -1)

# %%
fig, ax = plt.subplots(1, 10, figsize=(10, 1))

for i in range(10):
    a = np.random.randint(0,7000)
    ax[i].set_axis_off()
    ax[i].imshow(x_train[a])
    print(y_train[a])
# Out:
# [1]
# [6]
# [5]
# [3]
# [4]
# [1]
# [1]
# [2]
# [9]
# [8]

# %%
x_train = x_train[...,np.newaxis]
x_test = x_test[...,np.newaxis]
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (73257, 32, 32, 1) (73257, 1)
# (26032, 32, 32, 1) (26032, 1)

# %%
input_shape = x_train[1].shape

# %% [markdown]
# ## 2. MLP neural network classifier
# * Build an MLP classifier model using the Sequential API. Your model should use only Flatten and Dense layers, with the final layer having a 10-way softmax output.
# * You should design and build the model yourself. Feel free to experiment with different MLP architectures. _Hint: to achieve a reasonable accuracy you won't need to use more than 4 or 5 layers._
# * Print out the model summary (using the summary() method)
# * Compile and train the model (we recommend a maximum of 30 epochs), making use of both training and validation sets during the training run.
# * Your model should track at least one appropriate metric, and use at least two callbacks during training, one of which should be a ModelCheckpoint callback.
# * As a guide, you should aim to achieve a final categorical cross entropy training loss of less than 1.0 (the validation loss might be higher).
# * Plot the learning curves for loss vs epoch and accuracy vs epoch for both training and validation sets.
# * Compute and display the loss and accuracy of the trained model on the test set.

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
def get_callbacks(model_name):
  checkpoint_path = 'model_checkpoints/checkpoint'+ model_name
  checkpoint = ModelCheckpoint(filepath = checkpoint_path,
                             frequency = 'epoch',
                             save_weights_only = True,
                             verbose = 1,
                             save_best_only = True
                            )
  early_stopper = EarlyStopping(monitor = 'val_loss',
                              patience = 5,
                              mode = 'auto')
  return (checkpoint, early_stopper)

# %%
def get_dense_model():
  model_dense = Sequential([
                      Flatten(input_shape = input_shape),
                      Dense(units = 256,activation = 'relu'),
                      Dense(units = 128, activation = 'relu'),
                      Dense(units = 128, activation = 'relu'),
                      Dense(units = 10, activation = 'softmax')
  ])
  model_dense.compile(optimizer = 'adam',
                      loss = 'sparse_categorical_crossentropy',
                      metrics = ['accuracy'])
  return model_dense

# %%
model_dense = get_dense_model()
model_dense.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               262400
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 313,098
# Trainable params: 313,098
# Non-trainable params: 0
# _________________________________________________________________

# %%
# One-hot encoding of train and test labels

# lb = LabelBinarizer()
# y_train = lb.fit_transform(y_train)
# y_test = lb.fit_transform(y_test)

# %%
history = model_dense.fit(x_train, y_train, 
                          validation_split=0.2, epochs = 30, 
                          batch_size = 128, 
                          callbacks = [get_callbacks('model_dense')], verbose = 1)
# Out:
# Epoch 1/30
# 447/458 [============================>.] - ETA: 0s - loss: 9.2749 - accuracy: 0.1449
# Epoch 00001: val_loss improved from inf to 2.93617, saving model to model_checkpoints/checkpointmodel_dense
# 458/458 [==============================] - 1s 3ms/step - loss: 9.1260 - accuracy: 0.1465 - val_loss: 2.9362 - val_accuracy: 0.1704
# Epoch 2/30
# 439/458 [===========================>..] - ETA: 0s - loss: 2.2566 - accuracy: 0.3120
# Epoch 00002: val_loss improved from 2.93617 to 1.85218, saving model to model_checkpoints/checkpointmodel_dense
# 458/458 [==============================] - 1s 3ms/step - loss: 2.2403 - accuracy: 0.3154 - val_loss: 1.8522 - val_accuracy: 0.4178
# Epoch 3/30
# 447/458 [============================>.] - ETA: 0s - loss: 1.7020 - accuracy: 0.4573
# Epoch 00003: val_loss improved from 1.85218 to 1.52918, saving model to model_checkpoints/checkpointmodel_dense
# 458/458 [==============================] - 1s 3ms/step - loss: 1.7000 - accuracy: 0.4579 - val_loss: 1.5292 - val_accuracy: 0.5072
# Epoch 4/30
# 457/458 [============================>.] - ETA: 0s - loss: 1.4401 - accuracy: 0.5420
# Epoch 00004: val_loss improved from 1.52918 to 1.39618, saving model to model_checkpoints/checkpointmodel_dense
# 458/458 [==============================] - 1s 3ms/step - loss: 1.4403 - accuracy: 0.5421 - val_loss: 1.3962 - val_accuracy: 0.5583
# Epoch 5/30
# 454/458 [============================>.] - ETA: 0s - loss: 1.3481 - accuracy: 0.5784
# Epoch 00005: val_loss improved from 1.39618 to 1.37807, saving model to model_checkpoints/checkpointmodel_dense
# 458/458 [==============================] - 1s 3ms/step - loss: 1.3475 - accuracy: 0.5785 - val_loss: 1.3781 - val_accuracy: 0.5749
# Epoch 6/30
# 435/458 [===========================>..] - ETA: 0s - loss: 1.2738 - accuracy: 0.6016
# Epoch 00006: val_loss improved from 1.37807 to 1.34107, saving model to model_checkpoints/checkpointmodel_dense
# 458/458 [==============================] - 1s 3ms/step - loss: 1.2745 - accuracy: 0.6020 - val_loss: 1.3411 - val_accuracy: 0.5857
# Epoch 7/30
# 436/458 [===========================>..] - ETA: 0s - loss: 1.2206 - accuracy: 0.6239
# Epoch 00007: val_loss improved from 1.34107 to 1.24214, saving model to model_checkpoints/checkpointmodel_dense
# 458/458 [==============================] - 1s 3ms/step - loss: 1.2189 - accuracy: 0.6246 - val_loss: 1.2421 - val_accuracy: 0.6188
# Epoch 8/30
# 441/458 [===========================>..] - ETA: 0s - loss: 1.2125 - accuracy: 0.6273
# Epoch 00008: val_loss improved from 1.24214 to 1.19940, saving model to model_checkpoints/checkpointmodel_dense
# 458/458 [==============================] - 1s 3ms/step - loss: 1.2100 - accuracy: 0.6281 - val_loss: 1.1994 - val_accuracy: 0.6222
# Epoch 9/30
# 451/458 [============================>.] - ETA: 0s - loss: 1.1473 - accuracy: 0.6475
# Epoch 00009: val_loss improved from 1.19940 to 1.16678, saving model to model_checkpoints/checkpointmodel_dense
# 458/458 [==============================] - 1s 3ms/step - loss: 1.1479 - accuracy: 0.6474 - val_loss: 1.1668 - val_accuracy: 0.6478
# Epoch 10/30
# 455/458 [============================>.] - ETA: 0s - loss: 1.1213 - accuracy: 0.6571
# Epoch 00010: val_loss improved from 1.16678 to 1.12529, saving model to model_checkpoints/checkpointmodel_dense
# 458/458 [==============================] - 1s 3ms/step - loss: 1.1207 - accuracy: 0.6571 - val_loss: 1.1253 - val_accuracy: 0.6596
# Epoch 11/30
# 456/458 [============================>.] - ETA: 0s - loss: 1.1075 - accuracy: 0.6601
# Epoch 00011: val_loss improved from 1.12529 to 1.10039, saving model to model_checkpoints/checkpointmodel_dense
# 458/458 [==============================] - 1s 3ms/step - loss: 1.1074 - accuracy: 0.6601 - val_loss: 1.1004 - val_accuracy: 0.6685
# Epoch 12/30
# 458/458 [==============================] - ETA: 0s - loss: 1.0926 - accuracy: 0.6655
# Epoch 00012: val_loss did not improve from 1.10039
# 458/458 [==============================] - 1s 3ms/step - loss: 1.0926 - accuracy: 0.6655 - val_loss: 1.1093 - val_accuracy: 0.6620
# Epoch 13/30
# 449/458 [============================>.] - ETA: 0s - loss: 1.0650 - accuracy: 0.6727
# Epoch 00013: val_loss did not improve from 1.10039
# 458/458 [==============================] - 1s 3ms/step - loss: 1.0644 - accuracy: 0.6729 - val_loss: 1.1244 - val_accuracy: 0.6421
# Epoch 14/30
# 449/458 [============================>.] - ETA: 0s - loss: 1.0151 - accuracy: 0.6892
# Epoch 00014: val_loss did not improve from 1.10039
# 458/458 [==============================] - 1s 3ms/step - loss: 1.0146 - accuracy: 0.6895 - val_loss: 1.1152 - val_accuracy: 0.6631
# Epoch 15/30
# 444/458 [============================>.] - ETA: 0s - loss: 0.9965 - accuracy: 0.6955
# Epoch 00015: val_loss improved from 1.10039 to 1.03301, saving model to model_checkpoints/checkpointmodel_dense
# 458/458 [==============================] - 1s 3ms/step - loss: 0.9940 - accuracy: 0.6959 - val_loss: 1.0330 - val_accuracy: 0.6883
# Epoch 16/30
# 436/458 [===========================>..] - ETA: 0s - loss: 0.9866 - accuracy: 0.6989
# Epoch 00016: val_loss improved from 1.03301 to 0.91672, saving model to model_checkpoints/checkpointmodel_dense
# 458/458 [==============================] - 1s 3ms/step - loss: 0.9823 - accuracy: 0.7006 - val_loss: 0.9167 - val_accuracy: 0.7253
# Epoch 17/30
# 458/458 [==============================] - ETA: 0s - loss: 0.9428 - accuracy: 0.7124
# Epoch 00017: val_loss did not improve from 0.91672
# 458/458 [==============================] - 1s 3ms/step - loss: 0.9428 - accuracy: 0.7124 - val_loss: 1.0467 - val_accuracy: 0.6831
# Epoch 18/30
# 445/458 [============================>.] - ETA: 0s - loss: 0.9279 - accuracy: 0.7144
# Epoch 00018: val_loss did not improve from 0.91672
# 458/458 [==============================] - 1s 3ms/step - loss: 0.9283 - accuracy: 0.7143 - val_loss: 0.9665 - val_accuracy: 0.7100
# Epoch 19/30
# 436/458 [===========================>..] - ETA: 0s - loss: 0.9120 - accuracy: 0.7209
# Epoch 00019: val_loss improved from 0.91672 to 0.84333, saving model to model_checkpoints/checkpointmodel_dense
# 458/458 [==============================] - 1s 3ms/step - loss: 0.9094 - accuracy: 0.7221 - val_loss: 0.8433 - val_accuracy: 0.7516
# Epoch 20/30
# 451/458 [============================>.] - ETA: 0s - loss: 0.8855 - accuracy: 0.7295
# Epoch 00020: val_loss did not improve from 0.84333
# 458/458 [==============================] - 1s 3ms/step - loss: 0.8843 - accuracy: 0.7299 - val_loss: 0.9004 - val_accuracy: 0.7283
# Epoch 21/30
# 449/458 [============================>.] - ETA: 0s - loss: 0.8745 - accuracy: 0.7332
# Epoch 00021: val_loss did not improve from 0.84333
# 458/458 [==============================] - 1s 3ms/step - loss: 0.8731 - accuracy: 0.7335 - val_loss: 0.9487 - val_accuracy: 0.7129
# Epoch 22/30
# 437/458 [===========================>..] - ETA: 0s - loss: 0.8354 - accuracy: 0.7457
# Epoch 00022: val_loss did not improve from 0.84333
# 458/458 [==============================] - 1s 3ms/step - loss: 0.8353 - accuracy: 0.7454 - val_loss: 0.8616 - val_accuracy: 0.7471
# Epoch 23/30
# 442/458 [===========================>..] - ETA: 0s - loss: 0.8386 - accuracy: 0.7433
# Epoch 00023: val_loss did not improve from 0.84333
# 458/458 [==============================] - 1s 3ms/step - loss: 0.8373 - accuracy: 0.7440 - val_loss: 0.9726 - val_accuracy: 0.7043
# Epoch 24/30
# 449/458 [============================>.] - ETA: 0s - loss: 0.8341 - accuracy: 0.7435
# Epoch 00024: val_loss did not improve from 0.84333
# 458/458 [==============================] - 1s 3ms/step - loss: 0.8335 - accuracy: 0.7435 - val_loss: 0.8772 - val_accuracy: 0.7354

# %%
loss_train = history.history['loss']
loss_val = history.history['val_loss']
epochs = range(1,len(history.history['accuracy'])+1)
plt.plot(epochs, loss_train, 'g', label='Training loss')
plt.plot(epochs, loss_val, 'b', label='validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
loss_train = history.history['accuracy']
loss_val = history.history['val_accuracy']
epochs = range(1,len(history.history['accuracy'])+1)
plt.plot(epochs, loss_train, 'g', label='Training loss')
plt.plot(epochs, loss_val, 'b', label='validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
history_test = model_dense.evaluate(x_test, y_test, batch_size = 32)
print(history_test)
# Out:
# 814/814 [==============================] - 1s 2ms/step - loss: 0.9834 - accuracy: 0.7153
# [0.9833534359931946, 0.7152734994888306]

# %% [markdown]
# ## 3. CNN neural network classifier
# * Build a CNN classifier model using the Sequential API. Your model should use the Conv2D, MaxPool2D, BatchNormalization, Flatten, Dense and Dropout layers. The final layer should again have a 10-way softmax output.
# * You should design and build the model yourself. Feel free to experiment with different CNN architectures. _Hint: to achieve a reasonable accuracy you won't need to use more than 2 or 3 convolutional layers and 2 fully connected layers.)_
# * The CNN model should use fewer trainable parameters than your MLP model.
# * Compile and train the model (we recommend a maximum of 30 epochs), making use of both training and validation sets during the training run.
# * Your model should track at least one appropriate metric, and use at least two callbacks during training, one of which should be a ModelCheckpoint callback.
# * You should aim to beat the MLP model performance with fewer parameters!
# * Plot the learning curves for loss vs epoch and accuracy vs epoch for both training and validation sets.
# * Compute and display the loss and accuracy of the trained model on the test set.

# %%
from tensorflow.keras.layers import Conv2D, MaxPool2D, BatchNormalization, Dropout

# %%
def get_conv_model():
  model_conv = Sequential([
                      Conv2D(filters = 64, kernel_size = (3,3), 
                             padding = 'same', 
                             input_shape = input_shape, 
                             activation = 'relu'),
                      BatchNormalization(),
                      Conv2D(filters = 64, kernel_size = (3,3),
                             padding = 'same', activation = 'relu'),
                      MaxPool2D((3,3)),
                      Dropout(0.2),
                      Conv2D(filters = 64, kernel_size = (3,3), 
                             padding = 'same', activation = 'relu'),
                      MaxPool2D((3,3)),
                      Dropout(0.2),
                      Flatten(),
                      Dense(units = 64, activation = 'relu'),
                      BatchNormalization(),
                      Dense(units = 10, activation = 'softmax')
  ])
  model_conv.compile(optimizer = 'adam', 
                     loss = 'sparse_categorical_crossentropy',
                     metrics = ['accuracy'])
  return model_conv

# %%
model_conv = get_conv_model()
model_conv.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 64)        640
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 64)        256
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 10, 10, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 10, 10, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 3, 3, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 3, 3, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 576)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                36928
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64)                256
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                650
# =================================================================
# Total params: 112,586
# Trainable params: 112,330
# Non-trainable params: 256
# _________________________________________________________________

# %%
history = model_conv.fit(x_train, y_train, 
                         validation_split=0.15, epochs = 30,
                         batch_size = 128, 
                         callbacks = [get_callbacks('model_conv')],
                         verbose = 1)
# Out:
# Epoch 1/30
# 487/487 [==============================] - ETA: 0s - loss: 1.0536 - accuracy: 0.6610
# Epoch 00001: val_loss improved from inf to 0.52269, saving model to model_checkpoints/checkpointmodel_conv
# 487/487 [==============================] - 8s 16ms/step - loss: 1.0536 - accuracy: 0.6610 - val_loss: 0.5227 - val_accuracy: 0.8468
# Epoch 2/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.5306 - accuracy: 0.8366
# Epoch 00002: val_loss improved from 0.52269 to 0.43959, saving model to model_checkpoints/checkpointmodel_conv
# 487/487 [==============================] - 7s 15ms/step - loss: 0.5303 - accuracy: 0.8367 - val_loss: 0.4396 - val_accuracy: 0.8729
# Epoch 3/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.4483 - accuracy: 0.8618
# Epoch 00003: val_loss improved from 0.43959 to 0.36670, saving model to model_checkpoints/checkpointmodel_conv
# 487/487 [==============================] - 7s 15ms/step - loss: 0.4480 - accuracy: 0.8618 - val_loss: 0.3667 - val_accuracy: 0.8934
# Epoch 4/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.4064 - accuracy: 0.8742
# Epoch 00004: val_loss improved from 0.36670 to 0.36525, saving model to model_checkpoints/checkpointmodel_conv
# 487/487 [==============================] - 7s 15ms/step - loss: 0.4064 - accuracy: 0.8743 - val_loss: 0.3652 - val_accuracy: 0.8913
# Epoch 5/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.3734 - accuracy: 0.8868
# Epoch 00005: val_loss did not improve from 0.36525
# 487/487 [==============================] - 7s 15ms/step - loss: 0.3735 - accuracy: 0.8867 - val_loss: 0.3982 - val_accuracy: 0.8921
# Epoch 6/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.3547 - accuracy: 0.8920
# Epoch 00006: val_loss improved from 0.36525 to 0.33786, saving model to model_checkpoints/checkpointmodel_conv
# 487/487 [==============================] - 7s 15ms/step - loss: 0.3548 - accuracy: 0.8920 - val_loss: 0.3379 - val_accuracy: 0.8980
# Epoch 7/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.3394 - accuracy: 0.8959
# Epoch 00007: val_loss did not improve from 0.33786
# 487/487 [==============================] - 7s 15ms/step - loss: 0.3394 - accuracy: 0.8959 - val_loss: 0.3439 - val_accuracy: 0.9001
# Epoch 8/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.3207 - accuracy: 0.9019
# Epoch 00008: val_loss improved from 0.33786 to 0.28073, saving model to model_checkpoints/checkpointmodel_conv
# 487/487 [==============================] - 7s 15ms/step - loss: 0.3210 - accuracy: 0.9017 - val_loss: 0.2807 - val_accuracy: 0.9166
# Epoch 9/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.3076 - accuracy: 0.9074
# Epoch 00009: val_loss did not improve from 0.28073
# 487/487 [==============================] - 7s 15ms/step - loss: 0.3079 - accuracy: 0.9074 - val_loss: 0.3590 - val_accuracy: 0.8920
# Epoch 10/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.2954 - accuracy: 0.9096
# Epoch 00010: val_loss did not improve from 0.28073
# 487/487 [==============================] - 7s 15ms/step - loss: 0.2955 - accuracy: 0.9096 - val_loss: 0.3305 - val_accuracy: 0.9069
# Epoch 11/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.2865 - accuracy: 0.9127
# Epoch 00011: val_loss improved from 0.28073 to 0.27278, saving model to model_checkpoints/checkpointmodel_conv
# 487/487 [==============================] - 7s 15ms/step - loss: 0.2866 - accuracy: 0.9127 - val_loss: 0.2728 - val_accuracy: 0.9202
# Epoch 12/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.2746 - accuracy: 0.9158
# Epoch 00012: val_loss improved from 0.27278 to 0.27056, saving model to model_checkpoints/checkpointmodel_conv
# 487/487 [==============================] - 7s 15ms/step - loss: 0.2746 - accuracy: 0.9158 - val_loss: 0.2706 - val_accuracy: 0.9231
# Epoch 13/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.2714 - accuracy: 0.9163
# Epoch 00013: val_loss did not improve from 0.27056
# 487/487 [==============================] - 7s 15ms/step - loss: 0.2716 - accuracy: 0.9163 - val_loss: 0.2867 - val_accuracy: 0.9178
# Epoch 14/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.2623 - accuracy: 0.9205
# Epoch 00014: val_loss did not improve from 0.27056
# 487/487 [==============================] - 7s 15ms/step - loss: 0.2622 - accuracy: 0.9205 - val_loss: 0.3146 - val_accuracy: 0.9064
# Epoch 15/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.2577 - accuracy: 0.9219
# Epoch 00015: val_loss did not improve from 0.27056
# 487/487 [==============================] - 7s 15ms/step - loss: 0.2577 - accuracy: 0.9219 - val_loss: 0.2838 - val_accuracy: 0.9145
# Epoch 16/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.2458 - accuracy: 0.9245
# Epoch 00016: val_loss did not improve from 0.27056
# 487/487 [==============================] - 7s 15ms/step - loss: 0.2458 - accuracy: 0.9245 - val_loss: 0.2839 - val_accuracy: 0.9172
# Epoch 17/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.2427 - accuracy: 0.9255
# Epoch 00017: val_loss improved from 0.27056 to 0.26135, saving model to model_checkpoints/checkpointmodel_conv
# 487/487 [==============================] - 7s 15ms/step - loss: 0.2427 - accuracy: 0.9255 - val_loss: 0.2613 - val_accuracy: 0.9244
# Epoch 18/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.2376 - accuracy: 0.9278
# Epoch 00018: val_loss improved from 0.26135 to 0.25906, saving model to model_checkpoints/checkpointmodel_conv
# 487/487 [==============================] - 7s 15ms/step - loss: 0.2375 - accuracy: 0.9279 - val_loss: 0.2591 - val_accuracy: 0.9240
# Epoch 19/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.2354 - accuracy: 0.9270
# Epoch 00019: val_loss did not improve from 0.25906
# 487/487 [==============================] - 7s 15ms/step - loss: 0.2354 - accuracy: 0.9270 - val_loss: 0.2623 - val_accuracy: 0.9232
# Epoch 20/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.2277 - accuracy: 0.9308
# Epoch 00020: val_loss did not improve from 0.25906
# 487/487 [==============================] - 7s 15ms/step - loss: 0.2275 - accuracy: 0.9308 - val_loss: 0.2783 - val_accuracy: 0.9184
# Epoch 21/30
# 484/487 [============================>.] - ETA: 0s - loss: 0.2270 - accuracy: 0.9302
# Epoch 00021: val_loss did not improve from 0.25906
# 487/487 [==============================] - 7s 15ms/step - loss: 0.2268 - accuracy: 0.9303 - val_loss: 0.2676 - val_accuracy: 0.9209
# Epoch 22/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.2211 - accuracy: 0.9319
# Epoch 00022: val_loss improved from 0.25906 to 0.25428, saving model to model_checkpoints/checkpointmodel_conv
# 487/487 [==============================] - 7s 15ms/step - loss: 0.2215 - accuracy: 0.9318 - val_loss: 0.2543 - val_accuracy: 0.9264
# Epoch 23/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.2176 - accuracy: 0.9333
# Epoch 00023: val_loss did not improve from 0.25428
# 487/487 [==============================] - 7s 15ms/step - loss: 0.2176 - accuracy: 0.9333 - val_loss: 0.2705 - val_accuracy: 0.9216
# Epoch 24/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.2165 - accuracy: 0.9327
# Epoch 00024: val_loss improved from 0.25428 to 0.25008, saving model to model_checkpoints/checkpointmodel_conv
# 487/487 [==============================] - 7s 15ms/step - loss: 0.2164 - accuracy: 0.9326 - val_loss: 0.2501 - val_accuracy: 0.9271
# Epoch 25/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.2132 - accuracy: 0.9346
# Epoch 00025: val_loss did not improve from 0.25008
# 487/487 [==============================] - 7s 15ms/step - loss: 0.2135 - accuracy: 0.9345 - val_loss: 0.2534 - val_accuracy: 0.9287
# Epoch 26/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.2093 - accuracy: 0.9352
# Epoch 00026: val_loss did not improve from 0.25008
# 487/487 [==============================] - 7s 15ms/step - loss: 0.2092 - accuracy: 0.9351 - val_loss: 0.2622 - val_accuracy: 0.9247
# Epoch 27/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.2071 - accuracy: 0.9349
# Epoch 00027: val_loss did not improve from 0.25008
# 487/487 [==============================] - 7s 15ms/step - loss: 0.2070 - accuracy: 0.9349 - val_loss: 0.2557 - val_accuracy: 0.9254
# Epoch 28/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.2030 - accuracy: 0.9377
# Epoch 00028: val_loss improved from 0.25008 to 0.24945, saving model to model_checkpoints/checkpointmodel_conv
# 487/487 [==============================] - 7s 15ms/step - loss: 0.2031 - accuracy: 0.9377 - val_loss: 0.2494 - val_accuracy: 0.9300
# Epoch 29/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.2023 - accuracy: 0.9375
# Epoch 00029: val_loss did not improve from 0.24945
# 487/487 [==============================] - 7s 15ms/step - loss: 0.2024 - accuracy: 0.9374 - val_loss: 0.2738 - val_accuracy: 0.9221
# Epoch 30/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.1982 - accuracy: 0.9386
# Epoch 00030: val_loss did not improve from 0.24945
# 487/487 [==============================] - 7s 15ms/step - loss: 0.1982 - accuracy: 0.9386 - val_loss: 0.2637 - val_accuracy: 0.9244

# %%
loss_train = history.history['loss']
loss_val = history.history['val_loss']
epochs = range(1,len(history.history['accuracy'])+1)
plt.plot(epochs, loss_train, 'g', label='Training loss')
plt.plot(epochs, loss_val, 'b', label='validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
loss_train = history.history['accuracy']
loss_val = history.history['val_accuracy']
epochs = range(1,len(history.history['accuracy'])+1)
plt.plot(epochs, loss_train, 'g', label='Training loss')
plt.plot(epochs, loss_val, 'b', label='validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
history_test = model_conv.evaluate(x_test, y_test, batch_size = 32)
# Out:
# 814/814 [==============================] - 2s 2ms/step - loss: 0.2705 - accuracy: 0.9235

# %%
print(history_test)
# Out:
# [0.27047616243362427, 0.9235172271728516]

# %% [markdown]
# ## 4. Get model predictions
# * Load the best weights for the MLP and CNN models that you saved during the training run.
# * Randomly select 5 images and corresponding labels from the test set and display the images with their labels.
# * Alongside the image and label, show each model’s predictive distribution as a bar chart, and the final model prediction given by the label with maximum probability.

# %%
model_dense = get_dense_model()
model_dense.load_weights('model_checkpoints/checkpointmodel_dense')

# %%
num_test_images = x_test.shape[0]

random_inx = np.random.choice(num_test_images, 5)
random_test_images = x_test[random_inx, ...]
random_test_labels = y_test[random_inx, ...]
predictions = model_dense.predict(random_test_images)
fig, axes = plt.subplots(5, 2, figsize=(16, 12))
fig.subplots_adjust(hspace=0.4, wspace=-0.2)
for i, (prediction, image, label) in enumerate(zip(predictions,
                                                   random_test_images,
                                                   random_test_labels)):
    axes[i, 0].imshow(np.squeeze(image))
    axes[i, 0].get_xaxis().set_visible(False)
    axes[i, 0].get_yaxis().set_visible(False)
    axes[i, 0].text(10., -1.5, f'Digit {label}')
    axes[i, 1].bar(np.arange(len(prediction)), prediction)
    axes[i, 1].set_xticks(np.arange(len(prediction)))
    axes[i, 1].set_title(f"Categorical distribution. Model prediction: {np.argmax(prediction)}")
plt.show()

# %%
model_conv = get_conv_model()
model_conv.load_weights('model_checkpoints/checkpointmodel_conv')

# %%
num_test_images = x_test.shape[0]

random_inx = np.random.choice(num_test_images, 5)
random_test_images = x_test[random_inx, ...]
random_test_labels = y_test[random_inx, ...]
predictions = model_conv.predict(random_test_images)
fig, axes = plt.subplots(5, 2, figsize=(16, 12))
fig.subplots_adjust(hspace=0.4, wspace=-0.2)
for i, (prediction, image, label) in enumerate(zip(predictions, 
                                                   random_test_images,
                                                   random_test_labels)):
    axes[i, 0].imshow(np.squeeze(image))
    axes[i, 0].get_xaxis().set_visible(False)
    axes[i, 0].get_yaxis().set_visible(False)
    axes[i, 0].text(10., -1.5, f'Digit {label}')
    axes[i, 1].bar(np.arange(len(prediction)), prediction)
    axes[i, 1].set_xticks(np.arange(len(prediction)))
    axes[i, 1].set_title(f"Categorical distribution. Model prediction: {np.argmax(prediction)}")
plt.show()
